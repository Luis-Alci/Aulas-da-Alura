# %%
print('Escola de Dados da Alura!')
# Out:
# Escola de Dados da Alura!

# %%
print('Nome: Luis')
print('Sobrenome: Ferreira')
# Out:
# Nome: Luis
# Sobrenome: Ferreira

# %%
print('L')
print('U')
print('I')
print('S')
# Out:
# L
# U
# I
# S

# %%
print('11 maio 1981')
# Out:
# 11 maio 1981

# %%
print('Ano atual: 2024')
# Out:
# Ano atual: 2024
